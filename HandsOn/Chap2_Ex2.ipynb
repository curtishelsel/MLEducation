# %% [markdown]
# # Chapter 2 - Exercise 2
#
# Try replacing GridSearchCV with RandomizedSearchCV.

# %% [markdown]
# ## Data Preparation

# %%
# Copied directly from the book to get data
import os
import tarfile
import urllib

DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    os.makedirs(housing_path, exist_ok=True)
    tgz_path = os.path.join(housing_path, "housing.tgz")
    urllib.request.urlretrieve(housing_url, tgz_path)
    housing_tgz = tarfile.open(tgz_path)
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()

fetch_housing_data()

# %%
# create a class to put the data into pandas dataframe

import pandas as pd

def load_housing_data(housing_path=HOUSING_PATH):
    csv_path = os.path.join(housing_path, 'housing.csv')
    return pd.read_csv(csv_path)

housing = load_housing_data()

# %%
import numpy as np
housing['income_cat'] = pd.cut(housing['median_income'],
                               bins=[0.0, 1.5, 3.0, 4.5, 6.0, np.inf],
                               labels=[1, 2, 3, 4, 5])

# %%
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 42)

for train_index, test_index in split.split(housing, housing['income_cat']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]
    
strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 12655    -121.46     38.52                29.0       3873.0           797.0  \
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value
# 12655      2237.0       706.0         2.1736             72100.0  \
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#       ocean_proximity income_cat
# 12655          INLAND          2
# 15502      NEAR OCEAN          5
# 2908           INLAND          2
# 14053      NEAR OCEAN          2
# 20496       <1H OCEAN          3
# ...               ...        ...
# 15174       <1H OCEAN          4
# 12661          INLAND          2
# 19263       <1H OCEAN          3
# 19140       <1H OCEAN          3
# 19773          INLAND          3
#
# [16512 rows x 11 columns]

# %%
for set_ in (strat_test_set, strat_train_set):
    set_.drop('income_cat', axis=1, inplace=True)

strat_train_set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms
# 12655    -121.46     38.52                29.0       3873.0           797.0  \
# 15502    -117.23     33.09                 7.0       5320.0           855.0
# 2908     -119.04     35.37                44.0       1618.0           310.0
# 14053    -117.13     32.75                24.0       1877.0           519.0
# 20496    -118.70     34.28                27.0       3536.0           646.0
# ...          ...       ...                 ...          ...             ...
# 15174    -117.07     33.03                14.0       6665.0          1231.0
# 12661    -121.42     38.51                15.0       7901.0          1422.0
# 19263    -122.72     38.44                48.0        707.0           166.0
# 19140    -122.70     38.31                14.0       3155.0           580.0
# 19773    -122.14     39.97                27.0       1079.0           222.0
#
#        population  households  median_income  median_house_value
# 12655      2237.0       706.0         2.1736             72100.0  \
# 15502      2015.0       768.0         6.3373            279600.0
# 2908        667.0       300.0         2.8750             82700.0
# 14053       898.0       483.0         2.2264            112500.0
# 20496      1837.0       580.0         4.4964            238300.0
# ...           ...         ...            ...                 ...
# 15174      2026.0      1001.0         5.0900            268500.0
# 12661      4769.0      1418.0         2.8139             90400.0
# 19263       458.0       172.0         3.1797            140400.0
# 19140      1208.0       501.0         4.1964            258100.0
# 19773       625.0       197.0         3.1319             62700.0
#
#       ocean_proximity
# 12655          INLAND
# 15502      NEAR OCEAN
# 2908           INLAND
# 14053      NEAR OCEAN
# 20496       <1H OCEAN
# ...               ...
# 15174       <1H OCEAN
# 12661          INLAND
# 19263       <1H OCEAN
# 19140       <1H OCEAN
# 19773          INLAND
#
# [16512 rows x 10 columns]

# %%
# Separate the training labels from the data
housing = strat_train_set.drop('median_house_value', axis=1)
housing_labels = strat_train_set['median_house_value'].copy()

# %%
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

from sklearn.base import BaseEstimator, TransformerMixin

rooms_ix, bedrooms_ix, population_ix, households_ix = 3, 4, 5, 6

class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    def __init__(self, add_bedrooms_per_room = True):
        self.add_bedrooms_per_room = add_bedrooms_per_room
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X):
        rooms_per_household = X[:, rooms_ix] / X[:, households_ix]
        population_per_household = X[:, population_ix] / X[:,  households_ix]
        if self.add_bedrooms_per_room:
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]
        else:
            return np.c_[X, rooms_per_household, population_per_household]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('attribs_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler()),
])

# %%
from sklearn.compose import ColumnTransformer

housing_num = housing.drop("ocean_proximity", axis=1)
num_attrib = list(housing_num)
cat_attrib = ['ocean_proximity']

full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attrib),
    ('cat', OneHotEncoder(), cat_attrib),
])

housing_prepared = full_pipeline.fit_transform(housing)
housing_prepared
# Out:
# array([[-0.94135046,  1.34743822,  0.02756357, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 1.17178212, -1.19243966, -1.72201763, ...,  0.        ,
#          0.        ,  1.        ],
#        [ 0.26758118, -0.1259716 ,  1.22045984, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-1.5707942 ,  1.31001828,  1.53856552, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.56080303,  1.2492109 , -1.1653327 , ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.28105026,  2.02567448, -0.13148926, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
from sklearn.svm import SVR
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import uniform

param_distributions = {
    'kernel' : ["linear", "poly", "rbf", "sigmoid"],
    'gamma' : ['scale', 'auto'],
    'C' : uniform(0.1, 200000.0),
}
    
svr = SVR()

random_search = RandomizedSearchCV(svr, param_distributions, 
                                   n_iter=50, cv=5, scoring='neg_mean_squared_error', 
                                   verbose=2, random_state=42)

random_search.fit(housing_prepared, housing_labels)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END ........C=74908.1237694725, gamma=scale, kernel=rbf; total time=   5.7s
# [CV] END ........C=74908.1237694725, gamma=scale, kernel=rbf; total time=   6.0s
# [CV] END ........C=74908.1237694725, gamma=scale, kernel=rbf; total time=   5.7s
# [CV] END ........C=74908.1237694725, gamma=scale, kernel=rbf; total time=   5.6s
# [CV] END ........C=74908.1237694725, gamma=scale, kernel=rbf; total time=   5.5s
# [CV] END ...C=146398.88836228102, gamma=scale, kernel=linear; total time=  12.2s
# [CV] END ...C=146398.88836228102, gamma=scale, kernel=linear; total time=  14.3s
# [CV] END ...C=146398.88836228102, gamma=scale, kernel=linear; total time=  18.5s
# [CV] END ...C=146398.88836228102, gamma=scale, kernel=linear; total time=  15.9s
# [CV] END ...C=146398.88836228102, gamma=scale, kernel=linear; total time=  14.2s
# [CV] END ......C=31203.828088487302, gamma=scale, kernel=rbf; total time=   5.2s
# [CV] END ......C=31203.828088487302, gamma=scale, kernel=rbf; total time=   5.2s
# [CV] END ......C=31203.828088487302, gamma=scale, kernel=rbf; total time=   5.2s
# [CV] END ......C
gamma=auto, kernel=rbf; total time=   5.3s
# [CV] END .......C=91214.0968434072, gamma=scale, kernel=poly; total time=  48.2s
# [CV] END .......C=91214.0968434072, gamma=scale, kernel=poly; total time=  55.0s
# [CV] END .......C=91214.0968434072, gamma=scale, kernel=poly; total time= 1.6min
# [CV] END .......C=91214.0968434072, gamma=scale, kernel=poly; total time=  48.0s
# [CV] END .......C=91214.0968434072, gamma=scale, kernel=poly; total time=  46.5s
# [CV] END ...C=39934.85643167195, gamma=scale, kernel=sigmoid; total time=   8.1s
# [CV] END ...C=39934.85643167195, gamma=scale, kernel=sigmoid; total time=   7.6s
# [CV] END ...C=39934.85643167195, gamma=scale, kernel=sigmoid; total time=   8.0s
# [CV] END ...C=39934.85643167195, gamma=scale, kernel=sigmoid; total time=   7.7s
# [CV] END ...C=39934.85643167195, gamma=scale, kernel=sigmoid; total time=   8.1s
# [CV] END ...C=118483.01377240849, gamma=scale, kernel=linear; total time=  13.0s
# [CV] END ...C=118483.01377240849, gamma=scale, kernel=linear; total time=  13.4s
# [CV] END ...C=118483.01377240849, gamma=scale, kernel=linear; total time=  12.5s
# [CV] END ...C=118483.01377240849, gamma=scale, kernel=linear; total time=  12.8s
# [CV] END ...C=118483.01377240849, gamma=scale, kernel=linear; total time=  13.6s
# [CV] END ...C=121509.07038028768, gamma=scale, kernel=linear; total time=  13.1s
# [CV] END ...C=121509.07038028768, gamma=scale, kernel=linear; total time=  12.9s
# [CV] END ...C=121509.07038028768, gamma=scale, kernel=linear; total time=  13.4s
# [CV] END ...C=121509.07038028768, gamma=scale, kernel=linear; total time=  13.9s
# [CV] END ...C=121509.07038028768, gamma=scale, kernel=linear; total time=  12.3s
# [CV] END ....C=13010.418597055903, gamma=auto, kernel=linear; total time=   4.6s
# [CV] END ....C=13010.418597055903, gamma=auto, kernel=linear; total time=   5.2s
# [CV] END ....C=13010.418597055903, gamma=auto, kernel=linear; total time=   4.5s
# [CV] END ....C=13010.418597055903, gamma=auto, kernel=linear; total time=   4.6s
# [CV] END ....C=13010.418597055903, gamma=auto, kernel=linear; total time=   4.3s
# [CV] END ......C=193126.50661491186, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END ......C=193126.50661491186, gamma=auto, kernel=poly; total time=  41.7s
# [CV] END ......C=193126.50661491186, gamma=auto, kernel=poly; total time=  55.3s
# [CV] END ......C=193126.50661491186, gamma=auto, kernel=poly; total time=  34.4s
# [CV] END ......C=193126.50661491186, gamma=auto, kernel=poly; total time= 1.1min
# [CV] END ......C=60922.85383467413, gamma=scale, kernel=poly; total time=  43.7s
# [CV] END ......C=60922.85383467413, gamma=scale, kernel=poly; total time=  45.6s
# [CV] END ......C=60922.85383467413, gamma=scale, kernel=poly; total time=  43.3s
# [CV] END ......C=60922.85383467413, gamma=scale, kernel=poly; total time=  23.6s
# [CV] END ......C=60922.85383467413, gamma=scale, kernel=poly; total time=  40.0s
# [CV] END ...C=136846.7053024314, gamma=scale, kernel=sigmoid; total time=   8.3s
# [CV] END ...C=136846.7053024314, gamma=scale, kernel=sigmoid; total time=   8.2s
# [CV] END ...C=136846.7053024314, gamma=scale, kernel=sigmoid; total time=   8.1s
gamma=scale, kernel=rbf; total time=   5.2s
# [CV] END ......C=1104.5234247204799, gamma=scale, kernel=rbf; total time=   5.3s
# [CV] END ......C=1104.5234247204799, gamma=scale, kernel=rbf; total time=   5.2s
# [CV] END ......C=1104.5234247204799, gamma=scale, kernel=rbf; total time=   5.3s
# [CV] END ......C=1104.5234247204799, gamma=scale, kernel=rbf; total time=   5.2s
# [CV] END ......C=141371.56876952344, gamma=scale, kernel=rbf; total time=   6.0s
# [CV] END ......C=141371.56876952344, gamma=scale, kernel=rbf; total time=   6.3s
# [CV] END ......C=141371.56876952344, gamma=scale, kernel=rbf; total time=   6.2s
# [CV] END ......C=141371.56876952344, gamma=scale, kernel=rbf; total time=   6.2s
# [CV] END ......C=141371.56876952344, gamma=scale, kernel=rbf; total time=   6.1s
# [CV] END .....C=154254.16933718915, gamma=scale, kernel=poly; total time= 2.5min
# [CV] END .....C=154254.16933718915, gamma=scale, kernel=poly; total time= 2.1min
# [CV] END .....C=154254.16933718915, gamma=scale, kernel=poly; total time= 3.2min
# [CV] END .....C=154254.16933718915, gamma=scale, kernel=poly; total time= 1.4min
# [CV] END .....C=154254.16933718915, gamma=scale, kernel=poly; total time= 2.7min
# [CV] END ...C=71693.24570885453, gamma=scale, kernel=sigmoid; total time=   8.4s
# [CV] END ...C=71693.24570885453, gamma=scale, kernel=sigmoid; total time=   7.9s
# [CV] END ...C=71693.24570885453, gamma=scale, kernel=sigmoid; total time=   8.7s
# [CV] END ...C=71693.24570885453, gamma=scale, kernel=sigmoid; total time=   8.0s
# [CV] END ...C=71693.24570885453, gamma=scale, kernel=sigmoid; total time=   8.4s
# [CV] END ....C=172620.7851751187, gamma=auto, kernel=sigmoid; total time=   8.2s
# [CV] END ....C=172620.7851751187, gamma=auto, kernel=sigmoid; total time=   7.9s
# [CV] END ....C=172620.7851751187, gamma=auto, kernel=sigmoid; total time=   7.9s
# [CV] END ....C=172620.7851751187, gamma=auto, kernel=sigmoid; total time=   7.9s
# [CV] END ....C=172620.7851751187, gamma=auto, kernel=sigmoid; total time=   8.3s
# [CV] END ........C=66179.70497052984, gamma=auto, kernel=rbf; total time=   5.5s
# [CV] END ........C=66179.70497052984, gamma=auto, kernel=rbf; total time=   5.6s
# [CV] END ........C=66179.70497052984, gamma=auto, kernel=rbf; total time=   5.5s
# [CV] END ........C=66179.70497052984, gamma=auto, kernel=rbf; total time=   5.6s
# [CV] END ........C=66179.70497052984, gamma=auto, kernel=rbf; total time=   5.5s
# [CV] END .....C=62196.56434313244, gamma=auto, kernel=linear; total time=   8.3s
# [CV] END .....C=62196.56434313244, gamma=auto, kernel=linear; total time=   9.1s
# [CV] END .....C=62196.56434313244, gamma=auto, kernel=linear; total time=   8.5s
# [CV] END .....C=62196.56434313244, gamma=auto, kernel=linear; total time=   8.8s
# [CV] END .....C=62196.56434313244, gamma=auto, kernel=linear; total time=   8.9s
# [CV] END ......C=145921.33566761282, gamma=auto, kernel=poly; total time=  52.7s
# [CV] END ......C=145921.33566761282, gamma=auto, kernel=poly; total time=  47.4s
# [CV] END ......C=145921.33566761282, gamma=auto, kernel=poly; total time=  37.8s
# [CV] END ......C=145921.33566761282, gamma=auto, kernel=poly; total time=  23.7s
# [CV] END ......C=145921.33566761282, gamma=auto, kernel=poly; total time=  50.5s
# [CV] END ......C=177442.64851526532, gamma=scale, kernel=rbf; total time=   6.6s
# [CV] END ......C=177442.64851526532, gamma=scale, kernel=rbf; total time=   6.6s
# [CV] END ......C=177442.64851526532, gamma=scale, kernel=rbf; total time=   6.2s
# [CV] END ......C=177442.64851526532, gamma=scale, kernel=rbf; total time=   6.3s
# [CV] END ......C=177442.64851526532, gamma=scale, kernel=rbf; total time=   6.5s
# [CV] END ........C=23918.94918766034, gamma=auto, kernel=rbf; total time=   5.2s
# [CV] END ........C=23918.94918766034, gamma=auto, kernel=rbf; total time=   5.2s
# [CV] END ........C=23918.94918766034, gamma=auto, kernel=rbf; total time=   5.2s
# [CV] END ........C=23918.94918766034, gamma=auto, kernel=rbf; total time=   5.2s
# [CV] END ........C=23918.94918766034, gamma=auto, kernel=rbf; total time=   5.2s
# [CV] END ........C=152157.1097233795, gamma=auto, kernel=rbf; total time=   6.0s
# [CV] END ........C=152157.1097233795, gamma=auto, kernel=rbf; total time=   5.8s
# [CV] END ........C=152157.1097233795, gamma=auto, kernel=rbf; total time=   6.1s
# [CV] END ........C=152157.1097233795, gamma=auto, kernel=rbf; total time=   6.1s
# [CV] END ........C=152157.1097233795, gamma=auto, kernel=rbf; total time=   6.0s
# [CV] END .......C=154193.5359909122, gamma=scale, kernel=rbf; total time=   6.3s
# [CV] END .......C=154193.5359909122, gamma=scale, kernel=rbf; total time=   6.3s
# [CV] END .......C=154193.5359909122, gamma=scale, kernel=rbf; total time=   6.4s
# [CV] END .......C=154193.5359909122, gamma=scale, kernel=rbf; total time=   6.6s
# [CV] END .......C=154193.5359909122, gamma=scale, kernel=rbf; total time=   6.1s
# [CV] END .....C=104546.66587639882, gamma=scale, kernel=poly; total time= 1.5min
# [CV] END .....C=104546.66587639882, gamma=scale, kernel=poly; total time=  52.6s
# [CV] END .....C=104546.66587639882, gamma=scale, kernel=poly; total time= 1.7min
# [CV] END .....C=104546.66587639882, gamma=scale, kernel=poly; total time=  55.5s
# [CV] END .....C=104546.66587639882, gamma=scale, kernel=poly; total time= 1.1min
# [CV] END .......C=5083.925348819038, gamma=scale, kernel=rbf; total time=   5.1s
# [CV] END .......C=5083.925348819038, gamma=scale, kernel=rbf; total time=   5.1s
# [CV] END .......C=5083.925348819038, gamma=scale, kernel=rbf; total time=   5.1s
# [CV] END .......C=5083.925348819038, gamma=scale, kernel=rbf; total time=   5.1s
# [CV] END .......C=5083.925348819038, gamma=scale, kernel=rbf; total time=   5.1s
# RandomizedSearchCV(cv=5, estimator=SVR(), n_iter=50,
#                    param_distributions={'C': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7fb89dfb7550>,
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['linear', 'poly', 'rbf',
#                                                    'sigmoid']},
#                    random_state=42, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
random_search.best_params_
# Out:
# {'C': 177442.64851526532, 'gamma': 'scale', 'kernel': 'rbf'}

# %%
from sklearn.metrics import mean_squared_error

model = random_search.best_estimator_

X_test = strat_test_set.drop('median_house_value', axis=1)
y_test = strat_test_set['median_house_value'].copy()

X_test_prepared = full_pipeline.transform(X_test)
predictions = model.predict(X_test_prepared)

mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)

rmse
# Out:
# 54398.12122444924

# %%
from scipy import stats

confidence = 0.95
squared_errors = (predictions - y_test) ** 2
np.sqrt(stats.t.interval(confidence, len(squared_errors)-1, loc=squared_errors.mean(), scale = stats.sem(squared_errors)))
# Out:
# array([52185.42344613, 56524.26704742])
